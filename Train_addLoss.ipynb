# %%
# !python3 train_addLoss.py --n_epochs 50 --dataroot "../dataset/ISTD_Dataset" \
 --decay_epoch 30 --batchSize 2 --output_dir "../output_addloss" --iter_loss 10\
 --snapshot_epochs 10 --gpu_id 3 2>&1 | tee ../addLoss.log
# Out:
# /media/ntu/volume1/home/s122md306_05/miniconda3/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /media/ntu/volume1/home/s122md306_05/miniconda3/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_BN_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_BN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN/train_addLoss.py:155: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   transforms.Resize(int(opt.size * 1.12), Image.BICUBIC),
# ...

# %%
# !python3 generate_output.py --dataroot "../dataset/ISTD_Dataset"\
--generated_dir "../generated_addLoss"\
--generator_A2B "../output_addloss_2023-02-08 21:04:27.968923/netG_A2B.pth" \
2>&1 | tee "../gen_log.log"
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN/generate_output.py:86: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   transforms.Resize((int(opt.size),int(opt.size)), Image.BICUBIC),
# /media/ntu/volume1/home/s122md306_05/miniconda3/lib/python3.10/site-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# using GPU: 3
# Namespace(batchSize=1, dataroot='../dataset/ISTD_Dataset', input_nc=3, output_nc=3, size=400, cuda=True, n_cpu=8, generator_A2B='../output_addloss_2023-02-08 21:04:27.968923/netG_A2B.pth', generator_B2A='output/netG_B2A.pth', generated_dir='../generated_addLoss', dataroot_A='../dataset/ISTD_Dataset/test/test_A', dataroot_B='../dataset/ISTD_Dataset/test/test_C', im_suf_A='.png', im_suf_B='.png')
# predicting: 1 / 540
# ...
