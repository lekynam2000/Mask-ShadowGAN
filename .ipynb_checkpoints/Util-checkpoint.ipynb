# %%
# !pwd
# Out:
# /media/ntu/volume1/home/s122md306_05

# %%
# %cd Mask-ShadowGAN/
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN

# %%
# !pwd
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN

# %%
# !ls ../dataset
# Out:
#  ISTD_Dataset   ISTD_dataset.zip  'view?usp=sharing'

# %%
# !python3 train_Mask-ShadowGAN --n_epochs 100 --dataroot "../dataset/ISTD_Dataset" \
 --decay_epoch 50 --batchSize 1 --output_dir "../output_2"\
 --snapshot_epochs 5 2>&1 | tee log
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN/train_Mask-ShadowGAN:139: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   transforms.Resize(int(opt.size * 1.12), Image.BICUBIC),
# /media/ntu/volume1/home/s122md306_05/miniconda3/lib/python3.10/site-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# Namespace(epoch=0, n_epochs=100, batchSize=1, dataroot='../dataset/ISTD_Dataset', lr=0.0002, decay_epoch=50, size=400, input_nc=3, output_nc=3, cuda=True, n_cpu=8, snapshot_epochs=5, resume=False, iter_loss=500, data_len=9999, output_dir='../output_2', log_path='../output_2/2022-12-29 22:18:50.229391.txt')
# ...

# %%
# !python3 generate_output.py --dataroot "../dataset/ISTD_Dataset"\
--generator_A2B "../output_2/netG_A2B.pth" \
2>&1 | tee log
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN/generate_output.py:85: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   transforms.Resize((int(opt.size),int(opt.size)), Image.BICUBIC),
# /media/ntu/volume1/home/s122md306_05/miniconda3/lib/python3.10/site-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# Namespace(batchSize=1, dataroot='../dataset/ISTD_Dataset', input_nc=3, output_nc=3, size=400, cuda=True, n_cpu=8, generator_A2B='../output_2/netG_A2B.pth', generator_B2A='output/netG_B2A.pth', generated_dir='../generated', dataroot_A='../dataset/ISTD_Dataset/test/test_A', dataroot_B='../dataset/ISTD_Dataset/test/test_C', im_suf_A='.png', im_suf_B='.png')
# predicting: 1 / 540
# Generated images 0001 of 0540
# predicting: 2 / 540
# ...

# %%
# !pwd
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN

# %%
# !python3 evaluate/utils.py --gt_dir "../dataset/ISTD_Dataset/test/test_C" \
--est_dir "../generated_baseline/shadow_free" --img_suf ".png"
# Out:
# 0it [00:00, ?it/s](480, 640, 3)
# 1it [00:00,  8.24it/s](480, 640, 3)
# 2it [00:00,  6.97it/s](480, 640, 3)
# 3it [00:00,  7.41it/s](480, 640, 3)
# 4it [00:00,  7.41it/s](480, 640, 3)
# 5it [00:00,  7.58it/s](480, 640, 3)
# 6it [00:00,  7.77it/s](480, 640, 3)
# 7it [00:00,  7.46it/s](480, 640, 3)
# 8it [00:01,  7.86it/s](480, 640, 3)
# 9it [00:01,  8.22it/s](480, 640, 3)
# 10it [00:01,  7.55it/s](480, 640, 3)
# 11it [00:01,  7.71it/s](480, 640, 3)
# 12it [00:01,  7.67it/s](480, 640, 3)
# 13it [00:01,  7.37it/s](480, 640, 3)
# 14it [00:01,  7.00it/s](480, 640, 3)
# 15it [00:01,  7.43it/s](480, 640, 3)
# 16it [00:02,  7.19it/s](480, 640, 3)
# 17it [00:02,  7.18it/s](480, 640, 3)
# 18it [00:02,  7.29it/s](480, 640, 3)
# 19it [00:02,  7.02it/s](480, 640, 3)
# 20it [00:02,  6.88it/s](480, 640, 3)
# 21it [00:02,  7.05it/s](480, 640, 3)
# 22it [00:03,  6.97it/s](480, 640, 3)
# 23it [00:03,  6.78it/s](480, 640, 3)
# 24it [00:03,  6.90it/s](480, 640, 3)
# 25it [00:03,  6.97it/s](480, 640, 3)
# ...
