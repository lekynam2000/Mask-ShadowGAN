# %%
# !pwd
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN

# %%
# %cd Mask-ShadowGAN/
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN

# %%
# !pwd
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN

# %%
# !ls ../dataset
# Out:
#  ISTD_Dataset   ISTD_dataset.zip  'view?usp=sharing'

# %%
# !python3 train_Mask-ShadowGAN --n_epochs 200 --dataroot "../dataset/ISTD_Dataset" \
 --decay_epoch 100 --batchSize 1 --output_dir "../output_200_epoches"\
 --snapshot_epochs 20 2>&1 | tee ../epoches_200.log
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN/train_Mask-ShadowGAN:141: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   transforms.Resize(int(opt.size * 1.12), Image.BICUBIC),
# /media/ntu/volume1/home/s122md306_05/miniconda3/lib/python3.10/site-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# using GPU: 3
# Namespace(epoch=0, n_epochs=200, batchSize=1, dataroot='../dataset/ISTD_Dataset', lr=0.0002, decay_epoch=100, size=400, input_nc=3, output_nc=3, cuda=True, n_cpu=8, snapshot_epochs=20, resume=False, iter_loss=500, data_len=9999, output_dir='../output_200_epoches', log_path='../output_200_epoches/2023-01-15 22:51:26.253207.txt')
# ...

# %%
# !python3 generate_output.py --dataroot "../dataset/ISTD_Dataset"\
--generated_dir "../generated_200_epoches"\
--generator_A2B "../output_200_epoches/netG_A2B.pth" \
2>&1 | tee "../gen_log"
# Out:
# /media/ntu/volume1/home/s122md306_05/Mask-ShadowGAN/generate_output.py:86: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   transforms.Resize((int(opt.size),int(opt.size)), Image.BICUBIC),
# /media/ntu/volume1/home/s122md306_05/miniconda3/lib/python3.10/site-packages/torchvision/transforms/transforms.py:329: UserWarning: Argument 'interpolation' of type int is deprecated since 0.13 and will be removed in 0.15. Please use InterpolationMode enum.
#   warnings.warn(
# using GPU: 3
# Namespace(batchSize=1, dataroot='../dataset/ISTD_Dataset', input_nc=3, output_nc=3, size=400, cuda=True, n_cpu=8, generator_A2B='../output_200_epoches/netG_A2B.pth', generator_B2A='output/netG_B2A.pth', generated_dir='../generated_200_epoches', dataroot_A='../dataset/ISTD_Dataset/test/test_A', dataroot_B='../dataset/ISTD_Dataset/test/test_C', im_suf_A='.png', im_suf_B='.png')
# predicting: 1 / 540
# Generated images 0001 of 0540
# ...

# %%
import torch
print(torch.cuda.current_device())
# Out:
# 0

# %%
# !python3 evaluate/utils.py --gt_dir "../dataset/ISTD_Dataset/test/test_C" \
--est_dir "../generated_200_epoches/shadow_free" --img_suf ".png"\
2>&1 | tee ../evaluate_200_epoches.log
# Out:
# 143it [00:32,  3.96it/s]gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# gt_img.shape: (480, 640, 3) est_img.shape: (480, 640, 3)
# ...

# %%
# !python3 playground/blur_tf.py
# Out:
# 2023-02-03 10:37:54.002177: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-03 10:37:56.264140: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-02-03 10:37:57.276214: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# ...

# %%
# !python3 loss_utils.py
# Out:
# [[[124. 124. 122.]
#   [125. 126. 123.]
#   [126. 128. 126.]
#   ...
#   [161. 183. 191.]
#   [162. 178. 183.]
#   [138. 142. 145.]]
#
#  [[125. 125. 125.]
#   [122. 122. 120.]
#   [122. 123. 120.]
#   ...
#   [170. 194. 201.]
#   [158. 172. 176.]
#   [136. 136. 139.]]
#
#  [[120. 120. 118.]
#   [122. 123. 121.]
#   [119. 121. 118.]
#   ...
#   [167. 193. 198.]
#   [157. 167. 172.]
#   [113. 110. 114.]]
#
#  ...
#
#  [[140. 141. 141.]
#   [136. 136. 137.]
#   [135. 136. 135.]
#   ...
#   [146. 139. 134.]
#   [157. 149. 143.]
#   [152. 143. 135.]]
#
#  [[136. 137. 136.]
#   [142. 143. 142.]
#   [143. 143. 142.]
#   ...
#   [149. 143. 138.]
#   [156. 148. 142.]
#   [149. 140. 132.]]
#
#  [[134. 135. 135.]
#   [136. 138. 136.]
#   [137. 138. 136.]
#   ...
#   [153. 146. 141.]
#   [166. 158. 151.]
#   [158. 149. 141.]]]
# Kernel shape: torch.Size([3, 1, 21, 21])
# tensor([[[[8.2882e-05, 1.2726e-04, 1.8677e-04,  ..., 1.8677e-04,
#            1.2726e-04, 8.2882e-05],
# ...
